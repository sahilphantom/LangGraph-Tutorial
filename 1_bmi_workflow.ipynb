# %%
{
 "cell_type": "code",
 "execution_count": 0,
 "id": "f3b753eb",
 "metadata": {},
 "outputs": [],
 "source": []
}
# Out:
# {'cell_type': 'code',
#  'execution_count': 0,
#  'id': 'f3b753eb',
#  'metadata': {},
#  'outputs': [],
#  'source': []}
